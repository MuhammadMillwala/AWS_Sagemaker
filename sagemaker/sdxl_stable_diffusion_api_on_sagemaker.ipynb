# %%
# !pip install "sagemaker==2.116.0" "huggingface_hub==0.10.1" --upgrade
# Out:
# Collecting sagemaker==2.116.0
#   Downloading sagemaker-2.116.0.tar.gz (592 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 592.4/592.4 kB 8.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting huggingface_hub==0.10.1
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 11.4 MB/s eta 0:00:00
# Collecting attrs<23,>=20.3.0 (from sagemaker==2.116.0)
#   Downloading attrs-22.2.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 8.4 MB/s eta 0:00:00
# Collecting boto3<2.0,>=1.20.21 (from sagemaker==2.116.0)
#   Downloading boto3-1.34.47-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: google-pasta in /usr/local/lib/python3.10/dist-packages (from sagemaker==2.116.0) (0.2.0)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from sagemaker==2.116.0) (1.25.2)
# Requirement already satisfied: protobuf<4.0,>=3.1 in /usr/local/lib/python3.10/dist-packages (from sagemaker==2.116.0) (3.20.3)
# Collecting protobuf3-to-dict<1.0,>=0.1.5 (from sagemaker==2.116.0)
#   Downloading protobuf3-to-dict-0.1.5.tar.gz (3.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting smdebug_rulesconfig==1.0.1 (from sagemaker==2.116.0)
#   Downloading smdebug_rulesconfig-1.0.1-py2.py3-none-any.whl (20 kB)
# Collecting importlib-metadata<5.0,>=1.4.0 (from sagemaker==2.116.0)
#   Downloading importlib_metadata-4.13.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from sagemaker==2.116.0) (23.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from sagemaker==2.116.0) (1.5.3)
# Collecting pathos (from sagemaker==2.116.0)
#   Downloading pathos-0.3.2-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 8.2 MB/s eta 0:00:00
# Collecting schema (from sagemaker==2.116.0)
#   Downloading schema-0.7.5-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.10.1) (3.13.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.10.1) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.10.1) (4.66.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.10.1) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.10.1) (4.9.0)
# Collecting botocore<1.35.0,>=1.34.47 (from boto3<2.0,>=1.20.21->sagemaker==2.116.0)
#   Downloading botocore-1.34.47-py3-none-any.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 36.7 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0,>=1.20.21->sagemaker==2.116.0)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3<2.0,>=1.20.21->sagemaker==2.116.0)
#   Downloading s3transfer-0.10.0-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<5.0,>=1.4.0->sagemaker==2.116.0) (3.17.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from protobuf3-to-dict<1.0,>=0.1.5->sagemaker==2.116.0) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->sagemaker==2.116.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->sagemaker==2.116.0) (2023.4)
# Collecting ppft>=1.7.6.8 (from pathos->sagemaker==2.116.0)
#   Downloading ppft-1.7.6.8-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 7.4 MB/s eta 0:00:00
# Collecting dill>=0.3.8 (from pathos->sagemaker==2.116.0)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.8 MB/s eta 0:00:00
# Collecting pox>=0.3.4 (from pathos->sagemaker==2.116.0)
#   Downloading pox-0.3.4-py3-none-any.whl (29 kB)
# Collecting multiprocess>=0.70.16 (from pathos->sagemaker==2.116.0)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub==0.10.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub==0.10.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub==0.10.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub==0.10.1) (2024.2.2)
# Requirement already satisfied: contextlib2>=0.5.5 in /usr/local/lib/python3.10/dist-packages (from schema->sagemaker==2.116.0) (21.6.0)
# Building wheels for collected packages: sagemaker, protobuf3-to-dict
#   Building wheel for sagemaker (setup.py) ... done
#   Created wheel for sagemaker: filename=sagemaker-2.116.0-py2.py3-none-any.whl size=809039 sha256=ff174bfaba80f1f8ec1e4f97b760e19e96d729a9fa07eed85266e35366e53d92
#   Stored in directory: /root/.cache/pip/wheels/3e/59/09/7dc5d159f54a089d620382b932ff3a03c948164dd502947369
#   Building wheel for protobuf3-to-dict (setup.py) ... done
#   Created wheel for protobuf3-to-dict: filename=protobuf3_to_dict-0.1.5-py3-none-any.whl size=4008 sha256=5f38f26f8f8c846bc6d934aef0651fc820befdbafc620254be22ed365a9de452
#   Stored in directory: /root/.cache/pip/wheels/12/3e/42/e783cdd4e7b8fda9bfc472eeb465bc9041bda90a3dbece8d74
# Successfully built sagemaker protobuf3-to-dict
# Installing collected packages: smdebug_rulesconfig, schema, protobuf3-to-dict, ppft, pox, jmespath, importlib-metadata, dill, attrs, multiprocess, huggingface_hub, botocore, s3transfer, pathos, boto3, sagemaker
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 7.0.1
#     Uninstalling importlib-metadata-7.0.1:
#       Successfully uninstalled importlib-metadata-7.0.1
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.2.0
#     Uninstalling attrs-23.2.0:
#       Successfully uninstalled attrs-23.2.0
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tokenizers 0.15.2 requires huggingface_hub<1.0,>=0.16.4, but you have huggingface-hub 0.10.1 which is incompatible.
# transformers 4.37.2 requires huggingface-hub<1.0,>=0.19.3, but you have huggingface-hub 0.10.1 which is incompatible.
# Successfully installed attrs-22.2.0 boto3-1.34.47 botocore-1.34.47 dill-0.3.8 huggingface_hub-0.10.1 importlib-metadata-4.13.0 jmespath-1.0.1 multiprocess-0.70.16 pathos-0.3.2 pox-0.3.4 ppft-1.7.6.8 protobuf3-to-dict-0.1.5 s3transfer-0.10.0 sagemaker-2.116.0 schema-0.7.5 smdebug_rulesconfig-1.0.1

# %%
# !pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1

# %%
import os

os.environ["AWS_ACCESS_KEY_ID"] = ""
os.environ["AWS_SECRET_ACCESS_KEY"] = ""
os.environ["AWS_DEFAULT_REGION"] = "us-east-1"

# %%
import sagemaker
import boto3
sess = sagemaker.Session()
from dotenv import load_dotenv
load_dotenv()

boto_session = boto3.setup_default_session(
    aws_access_key_id=os.environ.get('aws_access_key_id'),
    aws_secret_access_key=os.environ.get('aws_secret_access_key'),
    region_name=os.environ.get('region_name')
)

sess = sagemaker.Session(boto_session=boto_session)

print(f"sagemaker bucket: {sess.default_bucket()}")
print(f"sagemaker session region: {sess.boto_region_name}")
# Out:
# sagemaker bucket: sagemaker-us-east-1-643105839968
# sagemaker session region: us-east-1

# %%
# !mkdir code

# %%
# %%writefile code/requirements.txt
# diffusers==0.6.0
# transformers==4.23.1
# Out:
# Writing code/requirements.txt

# %%
# %%writefile code/inference.py
import base64
import torch
from io import BytesIO
from diffusers import StableDiffusionPipeline


def model_fn(model_dir):
    # Load stable diffusion and move it to the GPU
    pipe = StableDiffusionPipeline.from_pretrained(model_dir, torch_dtype=torch.float16)
    pipe = pipe.to("cuda")

    return pipe


def predict_fn(data, pipe):

    # get prompt & parameters
    prompt = data.pop("inputs", data)
    # set valid HP for stable diffusion
    num_inference_steps = data.pop("num_inference_steps", 20)
    guidance_scale = data.pop("guidance_scale", 7.5)
    num_images_per_prompt = data.pop("num_images_per_prompt", 1)

    # run generation with parameters
    generated_images = pipe(
        prompt,
        num_inference_steps=num_inference_steps,
        guidance_scale=guidance_scale,
        num_images_per_prompt=num_images_per_prompt,
    )["images"]

    # create response
    encoded_images = []
    for image in generated_images:
        buffered = BytesIO()
        image.save(buffered, format="JPEG")
        encoded_images.append(base64.b64encode(buffered.getvalue()).decode())

    # create response
    return {"generated_images": encoded_images}
# Out:
# Writing code/inference.py

# %%
# %env HF_TOKEN=''
# Out:
# env: HF_TOKEN='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

# %%
from distutils.dir_util import copy_tree
from pathlib import Path
from huggingface_hub import snapshot_download
import random

HF_MODEL_ID="stabilityai/sdxl-turbo"
HF_TOKEN=os.environ.get('HF_TOKEN') # your hf token: https://huggingface.co/settings/tokens
assert len(HF_TOKEN) > 0, "Please set HF_TOKEN to your huggingface token. You can find it here: https://huggingface.co/settings/tokens"

# download snapshot
snapshot_dir = snapshot_download(repo_id=HF_MODEL_ID,use_auth_token=HF_TOKEN)

# create model dir
model_tar = Path(f"model-{random.getrandbits(16)}")
model_tar.mkdir(exist_ok=True)

# copy snapshot to model dir
copy_tree(snapshot_dir, str(model_tar))
# Out:
# Fetching 39 files:   0%|          | 0/39 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/7.49k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.54k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/204k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/685 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/744k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/204k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/459 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.9G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/6.94G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/565 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/246M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/493M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/492M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/575 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.39G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.78G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.78G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/586 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/704 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/460 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/855 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.78k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.14G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.3G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/7.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.3G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/607 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/167M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/198M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/137M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/file_util.py in _copy_file_contents(src, dst, buffer_size)
#      57             try:
# ---> 58                 fdst.write(buf)
#      59             except OSError as e:
#
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# DistutilsFileError                        Traceback (most recent call last)
# <ipython-input-9-a06aa5f92291> in <cell line: 18>()
#      16
#      17 # copy snapshot to model dir
# ---> 18 copy_tree(snapshot_dir, str(model_tar))
#
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/dir_util.py in copy_tree(src, dst, preserve_mode, preserve_times, preserve_symlinks, update, verbose, dry_run)
#     171         elif os.path.isdir(src_name):
#     172             outputs.extend(
# --> 173                 copy_tree(
#     174                     src_name,
#     175                     dst_name,
#
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/dir_util.py in copy_tree(src, dst, preserve_mode, preserve_times, preserve_symlinks, update, verbose, dry_run)
#     183             )
#     184         else:
# --> 185             copy_file(
#     186                 src_name,
#     187                 dst_name,
#
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/file_util.py in copy_file(src, dst, preserve_mode, preserve_times, update, link, verbose, dry_run)
#     161     # Otherwise (non-Mac, not linking), copy the file contents and
#     162     # (optionally) copy the times and mode.
# --> 163     _copy_file_contents(src, dst)
#     164     if preserve_mode or preserve_times:
#     165         st = os.stat(src)
#
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/file_util.py in _copy_file_contents(src, dst, buffer_size)
#      58                 fdst.write(buf)
#      59             except OSError as e:
# ---> 60                 raise DistutilsFileError(
#      61                     "could not write to '{}': {}".format(dst, e.strerror)
#      62                 )
#
# DistutilsFileError: could not write to 'model-17195/unet/model.onnx_data': No space left on device

# %%
# copy code/ to model dir
copy_tree("code/", str(model_tar.joinpath("code")))
# Out:
# ['model-34200/code/inference.py', 'model-34200/code/requirements.txt']

# %%
import tarfile
import os

# helper to create the model.tar.gz
def compress(tar_dir=None,output_file="model.tar.gz"):
    parent_dir=os.getcwd()
    os.chdir(tar_dir)
    with tarfile.open(os.path.join(parent_dir, output_file), "w:gz") as tar:
        for item in os.listdir('.'):
          print(item)
          tar.add(item, arcname=item)
    os.chdir(parent_dir)

compress(str(model_tar))
# Out:
# vae
# feature_extractor
# scheduler
# unet
# .gitattributes
# model_index.json
# v1-variants-scores.jpg
# text_encoder
# code
# safety_checker
# README.md
# tokenizer

# %%
from sagemaker.s3 import S3Uploader

# upload model.tar.gz to s3
s3_model_uri=S3Uploader.upload(local_path="model.tar.gz", desired_s3_uri=f"s3://{sess.default_bucket()}/model")

print(f"model uploaded to: {s3_model_uri}")
# Out:
# model uploaded to: s3://sagemaker-us-east-1-643105839968/model/model.tar.gz

# %%
from sagemaker.huggingface.model import HuggingFaceModel


# create Hugging Face Model Class
huggingface_model = HuggingFaceModel(
   model_data='s3://sagemaker-us-east-1-643105839968/model/model.tar.gz',
   role='AmazonSageMaker-ExecutionRole-20240217T140781', # iam role with permissions to create an Endpoint
   transformers_version="4.17",  # transformers version used
   pytorch_version="1.10",       # pytorch version used
   py_version='py38',            # python version used
)

# deploy the endpoint endpoint
predictor = huggingface_model.deploy(
    initial_instance_count=1,
    instance_type="ml.g4dn.xlarge"
)
# Out:
# ---------!

# %%
import boto3
from PIL import Image
from io import BytesIO
from IPython.display import display
import base64
import matplotlib.pyplot as plt
import time
import json

# helper decoder
def decode_base64_image(image_string):
  base64_image = base64.b64decode(image_string)
  buffer = BytesIO(base64_image)
  return Image.open(buffer)

# display PIL images as grid
def display_images(images=None,columns=3, width=100, height=100):
    plt.figure(figsize=(width, height))
    for i, image in enumerate(images):
        plt.subplot(int(len(images) / columns + 1), columns, i + 1)
        plt.axis('off')
        plt.imshow(image)

start_time = time.time()
# run prediction

client = boto3.client('sagemaker-runtime')

prompt = "A cinematic shot of a colorful lion"

num_images_per_prompt = 1

payload = {
    "inputs": prompt,
    "num_images_per_prompt": num_images_per_prompt
}

serialized_payload = json.dumps(payload)  # Serialize the payload to JSON format

endpoint_name = "huggingface-pytorch-inference-2024-02-22-10-49-51-264"

response = client.invoke_endpoint(
    EndpointName=endpoint_name,
    Body=serialized_payload,
    ContentType='application/json'  # Specify the format of the payload
)

response_payload = json.loads(response['Body'].read().decode("utf-8"))

end_time = time.time()

elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")

# decode images
decoded_images = [decode_base64_image(image) for image in response_payload["generated_images"]]

# visualize generation
display_images(decoded_images)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-40bf14d5a262> in <cell line: 1>()
# ----> 1 import boto3
#       2 from PIL import Image
#       3 from io import BytesIO
#       4 from IPython.display import display
#       5 import base64
#
# ModuleNotFoundError: No module named 'boto3'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
